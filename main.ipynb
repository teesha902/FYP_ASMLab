# %% [markdown]
# # setup

# %%
# !conda env list
# Make sure the custom env is created and used
# Out:
# # conda environments:
# #
# base                     C:\Users\arite\miniconda3
# ASM_Lab               *  C:\Users\arite\miniconda3\envs\ASM_Lab

# %%
# %pip install -r requirements.txt

# %% [markdown]
# # DLC

# %% [markdown]
# # Analysis

# %% [markdown]
# Ensure that DLC csvs are in data/csv/ and the original videos are in data/videos

# %%
# !python scripts/LED_times.py --video_path data/videos/143-160
# Out:
#  total videos found are 53
# 160_M.mp4
# 100%|███████████████████████████████████████| 5400/5400 [03:22<00:00, 26.64it/s]
# ['160_M.mp4', '88.49', '93.46', 2653.0, 2802.0]
# 155_S.mp4
# 100%|███████████████████████████████████████| 5400/5400 [03:24<00:00, 26.45it/s]
# ['155_S.mp4', '89.52', '93.26', 2684.0, 2796.0]
# 157_F.mp4
# 100%|███████████████████████████████████████| 5370/5370 [03:21<00:00, 26.63it/s]
# ['157_F.mp4', '119.92', '123.89', 3595.0, 3714.0]
# 153_T.mp4
# 100%|███████████████████████████████████████| 5400/5400 [03:22<00:00, 26.66it/s]
# ['153_T.mp4', '89.56', '93.53', 2685.0, 2804.0]
# 144_M.mp4
# 100%|███████████████████████████████████████| 5400/5400 [03:21<00:00, 26.76it/s]
# ['144_M.mp4', '90.29', '94.26', 2707.0, 2826.0]
# 151_T.mp4
# 100%|███████████████████████████████████████| 5400/5400 [03:25<00:00, 26.34it/s]
# ['151_T.mp4', '89.32', '93.29', 2678.0, 2797.0]
# ['151_T.mp4', '149.32', '153.29', 4476.0, 4595.0]
# 155_F.mp4
# ...

# %%
# !python scripts/SUBSET_CSV_M.py
# Out:
# Found 107 csv files
# Traceback (most recent call last):
#   File "/Users/asmlabuser1/Scripts_Ari/scripts/SUBSET_CSV_M.py", line 477, in <module>
#     outfile = main(f, debug)
#   File "/Users/asmlabuser1/Scripts_Ari/scripts/SUBSET_CSV_M.py", line 14, in main
#     full_path = (f.split("\\")[-1])
# AttributeError: 'PosixPath' object has no attribute 'split'

# %%
# !python saoirse_updated_scripts/SUBSET_CSV_M.py
# Out:
# 101_F
# Traceback (most recent call last):
#   File "/Users/asmlabuser1/Scripts_Ari/saoirse_updated_scripts/SUBSET_CSV_M.py", line 22, in <module>
#     exp_time =int(csv.iloc[0,22])
#   File "/Users/asmlabuser1/opt/anaconda3/envs/ari_cv2/lib/python3.9/site-packages/pandas/core/indexing.py", line 1066, in __getitem__
#     return self.obj._get_value(*key, takeable=self._takeable)
#   File "/Users/asmlabuser1/opt/anaconda3/envs/ari_cv2/lib/python3.9/site-packages/pandas/core/frame.py", line 3912, in _get_value
#     series = self._ixs(col, axis=1)
#   File "/Users/asmlabuser1/opt/anaconda3/envs/ari_cv2/lib/python3.9/site-packages/pandas/core/frame.py", line 3726, in _ixs
#     label = self.columns[i]
#   File "/Users/asmlabuser1/opt/anaconda3/envs/ari_cv2/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 5363, in __getitem__
#     return getitem(key)
# IndexError: index 22 is out of bounds for axis 0 with size 21

# %%
print(LED_times)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(LED_times)
#
# NameError: name 'LED_times' is not defined

# %%
abc = {'Too many LED events': [1, 2], 'LED not observed': [3]}
print(len([i for i in abc.values()]))
# Out:
# 2
