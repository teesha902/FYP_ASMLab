# %% [markdown]
# # Use this notebook for processing data!

# %% [markdown]
# ## Setup

# %% [markdown]
# You should have created an anaconda virtual environment with python by this time. If not, try the setup section in the readme.
#
# Try running the cell below to check what environment this is currently running in. If the name printed is the correct environment name, the setup is done! You will just need to run the pip install command below to double-check all requirements are installed and found here too.

# %%
import sys
import os
kernel_name = os.path.basename(sys.executable.replace("/bin/python",""))
print(kernel_name)
# Out:
# ari_cv2

# %% [markdown]
# If the name printed is not correct environment but the environment is created, google instructions on changing jupyter notebook environment for your IDE. If you are using jupyter notebook/jupyter lab in the deafult chrome environment, then follow steps
#
# If the environments are not detected, that could either be that the notebook has never been run in this environment, or the interpreter is not detecting the environment correctly. You can either try to google and debug for your specific IDE, or go to command prompt/terminal and try activating the environment there. If that works, you can mostly run the commands yourself by copy pasting from here and running them in terminal.
#
# To run commands in terminal, make sure you activate the correct virtual env, and then remove the % sign for the cell right below, and the %run for the cells calling the scripts. Replace the %run with `python` or `python3` for running scripts (try `python` first).

# %%
# %pip install -r requirements.txt
# Out:
# ...
# ^C
# ERROR: Operation cancelled by user
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## DLC

# %% [markdown]
# # Analysis

# %% [markdown]
# Ensure that DLC csvs are in data/csv/ and the original videos are in data/videos. Otherwise, specify your own paths. Full descriptions for each script can be found in scripts/readme.md .
#
#
# **USAGE OF FLAGS:**
#
# These scripts are created to take user input in the form of flags. Flags are of the form `--<flag name>` and usually take in a value, like `--input_path ./data/csv`. However, if its a true/flase flag, just passing the flag like `--debug` works. If you need help or want to check what flags are present for the script, use the `%run <script name> --help` as shown below.

# %%
# %run scripts/LED_times.py --help
# Out:
# usage: LED_times.py [-h] [--video_path VIDEO_PATH] [--output_path OUTPUT_PATH]
#                     [--debug] [--vis] [--no_hist_thresh] [--max_led MAX_LED]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --video_path VIDEO_PATH
#                         the filepath to video files if not default
#   --output_path OUTPUT_PATH
#                         the filepath to output csv if not default
#   --debug               debug mode (default is false)
#   --vis                 visualise (default is false)
#   --no_hist_thresh      use histogram based thresholding (default is true)
#   --max_led MAX_LED     max number of LED events allowed (default is 2)

# %% [markdown]
# ### Generate LED Times

# %% [markdown]
# For generating LED times, the critical flags are `--video_path` giving the video path (default is data/videos/), `--output_path` giving the output path (default is data/output/), and `--max_led` (default is 2).
#
# For now, `--no_hist_thresh` is used as dynamic histogram thresholding yeilds worse results as compared to the static thresholds created.

# %% [markdown]
# `%run scripts/LED_times.py --video_path <path to video folder> --output_path <path to output folder> --no_hist_thresh <additional parameters>`

# %%
# %run scripts/LED_times.py --video_path data/videos/selected_d48_videos/vr03 --output_path data/output/selected_d48_videos_coords/vr03 --no_hist_thresh
# Out:
#  total videos found are 252
# d48_70_M1.mp4
# 100%|██████████| 3840/3840 [02:24<00:00, 26.66it/s]
# ['d48_70_M1.mp4', '59.89', '64.86', 1796.0, 1945.0, 418, 833]
# d48_37_M1.mp4
# 100%|██████████| 5400/5400 [03:21<00:00, 26.80it/s]
# ['d48_37_M1.mp4', '88.25', '93.26', 2646.0, 2796.0, 489, 817]
# d48_29_M1.mp4
# 100%|██████████| 5400/5400 [03:28<00:00, 25.87it/s]
# LED not observed in d48_29_M1.mp4
# d48_58_M1.mp4
# 100%|██████████| 3600/3600 [02:17<00:00, 26.19it/s]
# LED not observed in d48_58_M1.mp4
# d48_83_M1.mp4
# 100%|██████████| 3780/3780 [02:24<00:00, 26.14it/s]
# LED not observed in d48_83_M1.mp4
# d48_72_M1.mp4
# 100%|██████████| 3720/3720 [02:21<00:00, 26.37it/s]
# LED not observed in d48_72_M1.mp4
# d48_44_M1.mp4
# 100%|██████████| 5400/5400 [03:26<00:00, 26.09it/s]
# ['d48_44_M1.mp4', '89.22', '94.19', 2675.0, 2824.0, 432, 842]
# ['d48_44_M1.mp4', '149.22', '154.19', 4473.0, 4622.0, 432, 842]
# d48_48_M1.mp4
# 100%|██████████| 5400/5400 [03:29<00:00, 25.76it/s]
# ...

# %%
# %run scripts/LED_times.py --video_path data/videos/week_12/ --output_path data/output/week_12_coords/ --no_hist_thresh
# Out:
#  total videos found are 242
# 160_M.mp4
# 100%|██████████| 5400/5400 [03:23<00:00, 26.56it/s]
# ['160_M.mp4', '88.49', '93.46', 2653.0, 2802.0, 541, 540]
# 155_S.mp4
# 100%|██████████| 5400/5400 [03:25<00:00, 26.31it/s]
# ['155_S.mp4', '89.52', '93.26', 2684.0, 2796.0, 244, 272]
# 157_F.mp4
# 100%|██████████| 5370/5370 [03:26<00:00, 26.01it/s]
# ['157_F.mp4', '119.92', '123.89', 3595.0, 3714.0, 408, 615]
# 153_T.mp4
# 100%|██████████| 5400/5400 [03:29<00:00, 25.81it/s]
# ['153_T.mp4', '89.56', '93.53', 2685.0, 2804.0, 422, 526]
# 144_M.mp4
# 100%|██████████| 5400/5400 [03:27<00:00, 26.05it/s]
# ['144_M.mp4', '90.29', '94.26', 2707.0, 2826.0, 408, 687]
# 146_M.mp4
# 100%|██████████| 5400/5400 [03:27<00:00, 25.98it/s]
# LED not observed in 146_M.mp4
# 151_T.mp4
# 100%|██████████| 5400/5400 [03:28<00:00, 25.90it/s]
# ['151_T.mp4', '89.32', '93.29', 2678.0, 2797.0, 381, 578]
# ['151_T.mp4', '149.32', '153.29', 4476.0, 4595.0, 381, 578]
# 157_S.mp4
# ...

# %% [markdown]
# ### Process data to get analysed data (distance, velocity, acceleration, jitter, distance to surface, tail-to-head angle, more WIP)

# %% [markdown]
# This step will take the DLC csv outputs and do:
# 1. data integrity checks (null + low threshold + jitter) using `data_integrity.py`
# 2. convert pixels to mm
# 3. calculate distance, velocity and acc using `analysis.py`
#
# All of these are run using the one script, which is `data_mm_analyse.py`
#
# The critical flags are `--csv_path` to give DLC csv path if not ./data/csv/, `--output_path` to give output path if not ./data/output/mm_analyse, `--invalid_thresh` to set the likelihood threshold to be considered invalid if not 0.25, and `--percent_missing` to set the percentage threshold for considering a csv "problematic" if not 15%.
#
# A problems_csv.txt is also saved to output path, collating all the issues with the csvs for a detailed look.
#
# You can check if the correct number of files are being detected using the cell below by giving the path to `path_to_csv`.
#
# This takes about a minute to run on 240 files.

# %%
# check if the correct number of csvs are detected

from pathlib import Path

path_to_csv = Path("./data/csv/without_led/")
csv_files = list(path_to_csv.glob("**/*.csv"))
print(len(csv_files))
# Out:
# 241

# %%
# %run scripts/data_mm_analyse.py --csv_path "./data/csv/without_led/" --output_path "./data/output/week12_surface_led/" --LED_csv_path "./data/output/week_12_coords/LED_times.csv"
# Out:
# 241 csv files found
# 101_M.csv
# 0.54% missing data, 1.39% low likelihood data
# 0.13% of frames are jittery
# Saved to ./data/output/week12_surface_led/uroa/1/101_M.csv
# 144_M.csv
# 2.27% missing data, 11.58% low likelihood data
# 5.35% of frames are jittery
# Saved to ./data/output/week12_surface_led/uroa/1/144_M.csv
# 116_T.csv
# 2.39% missing data, 3.90% low likelihood data
# 0.50% of frames are jittery
# Saved to ./data/output/week12_surface_led/uroa/1/116_T.csv
# 125_M.csv
# LED file not found for 125_M.csv
# 25.70% missing data, 17.06% low likelihood data
# Too much missing data in 125_M.csv
# Too much low likelihood data in 125_M.csv
# 12.10% of frames are jittery
# Saved to ./data/output/week12_surface_led/uroa/1/125_M.csv
# 114_T.csv
# LED file not found for 114_T.csv
# 3.17% missing data, 6.31% low likelihood data
# 0.02% of frames are jittery
# Saved to ./data/output/week12_surface_led/uroa/1/114_T.csv
# 103_M.csv
# 3.02% missing data, 5.81% low likelihood data
# ...

# %% [markdown]
# ## Testing cells (ignore anything below this)

# %% [markdown]
# 89 files with missing/low likelihood data (min 2 in row to be considered) during led at 0.1
#
# 54 files with missing/low likelihood data during led at 0.2
#
# 24 files with > 10% jittery frames in led timing
#
# 58 led files missing

# %%
#hist with lower limit applied
# %run -t scripts/LED_times.py --video_path data/videos/week_12 --output_path data/output/hist_exp/
# Out:
#  total videos found are 242
# 160_M.mp4
# 100%|██████████| 5400/5400 [03:25<00:00, 26.23it/s]
# ['160_M.mp4', '88.49', '93.46', 2653.0, 2802.0]
# 155_S.mp4
# 100%|██████████| 5400/5400 [03:24<00:00, 26.43it/s]
# ['155_S.mp4', '89.52', '93.26', 2684.0, 2796.0]
# 157_F.mp4
# 100%|██████████| 5370/5370 [03:22<00:00, 26.51it/s]
# ['157_F.mp4', '119.92', '123.89', 3595.0, 3714.0]
# 153_T.mp4
# 100%|██████████| 5400/5400 [03:24<00:00, 26.46it/s]
# ['153_T.mp4', '89.56', '93.53', 2685.0, 2804.0]
# 144_M.mp4
# 100%|██████████| 5400/5400 [03:25<00:00, 26.32it/s]
# ['144_M.mp4', '90.29', '94.26', 2707.0, 2826.0]
# 146_M.mp4
# 100%|██████████| 5400/5400 [03:23<00:00, 26.53it/s]
# LED not observed in 146_M.mp4
# 151_T.mp4
# 100%|██████████| 5400/5400 [03:23<00:00, 26.51it/s]
# ['151_T.mp4', '89.32', '93.29', 2678.0, 2797.0]
# ['151_T.mp4', '149.32', '153.29', 4476.0, 4595.0]
# 157_S.mp4
# 100%|██████████| 5400/5400 [03:19<00:00, 27.13it/s]
# LED not observed in 157_S.mp4
# 155_F.mp4
# ...

# %%
#hist with no lower limit
# Out:
#  total videos found are 242
# 160_M.mp4
# 100%|██████████| 5400/5400 [03:12<00:00, 28.07it/s]
# ['160_M.mp4', '88.49', '93.46', 2653.0, 2802.0]
# 155_S.mp4
# 100%|██████████| 5400/5400 [03:13<00:00, 27.93it/s]
# ['155_S.mp4', '89.52', '93.26', 2684.0, 2796.0]
# 157_F.mp4
# 100%|██████████| 5370/5370 [03:13<00:00, 27.77it/s]
# ['157_F.mp4', '119.92', '123.89', 3595.0, 3714.0]
# 153_T.mp4
# 100%|██████████| 5400/5400 [03:15<00:00, 27.63it/s]
# ['153_T.mp4', '89.56', '93.53', 2685.0, 2804.0]
# 144_M.mp4
# 100%|██████████| 5400/5400 [03:16<00:00, 27.52it/s]
# ['144_M.mp4', '90.29', '94.26', 2707.0, 2826.0]
# 146_M.mp4
# 100%|██████████| 5400/5400 [03:16<00:00, 27.48it/s]
# LED not observed in 146_M.mp4
# 151_T.mp4
# 100%|██████████| 5400/5400 [03:15<00:00, 27.59it/s]
# ['151_T.mp4', '89.32', '93.29', 2678.0, 2797.0]
# ['151_T.mp4', '149.32', '153.29', 4476.0, 4595.0]
# 157_S.mp4
# 100%|██████████| 5400/5400 [03:16<00:00, 27.51it/s]
# LED not observed in 157_S.mp4
# 155_F.mp4
# ...

# %%
# no hist
# Out:
#  total videos found are 242
# 160_M.mp4
# 100%|██████████| 5400/5400 [03:17<00:00, 27.41it/s]
# ['160_M.mp4', '88.49', '93.46', 2653.0, 2802.0]
# 155_S.mp4
# 100%|██████████| 5400/5400 [03:16<00:00, 27.49it/s]
# ['155_S.mp4', '89.52', '93.26', 2684.0, 2796.0]
# 157_F.mp4
# 100%|██████████| 5370/5370 [03:16<00:00, 27.27it/s]
# ['157_F.mp4', '119.92', '123.89', 3595.0, 3714.0]
# 153_T.mp4
# 100%|██████████| 5400/5400 [03:16<00:00, 27.55it/s]
# ['153_T.mp4', '89.56', '93.53', 2685.0, 2804.0]
# 144_M.mp4
# 100%|██████████| 5400/5400 [03:16<00:00, 27.43it/s]
# ['144_M.mp4', '90.29', '94.26', 2707.0, 2826.0]
# 146_M.mp4
# 100%|██████████| 5400/5400 [03:12<00:00, 28.11it/s]
# LED not observed in 146_M.mp4
# 151_T.mp4
# 100%|██████████| 5400/5400 [03:14<00:00, 27.72it/s]
# ['151_T.mp4', '89.32', '93.29', 2678.0, 2797.0]
# ['151_T.mp4', '149.32', '153.29', 4476.0, 4595.0]
# 157_S.mp4
# 100%|██████████| 5400/5400 [03:15<00:00, 27.57it/s]
# LED not observed in 157_S.mp4
# 155_F.mp4
# ...

# %%
from scripts.LED_times import *
video_path = Path("data/videos/week_12")
problem_vids = {'Too many LED events': ['148_F.mp4', '147_M.mp4', '156_F.mp4', '147_F.mp4', '125_S.mp4', '136_T.mp4', '137_T.mp4', '138_T.mp4', '114_W.mp4', '111_SU.mp4', '118_S.mp4', '133_F.mp4'], 'LED not observed': ['146_M.mp4', '157_S.mp4', '155_F.mp4', '148_T.mp4', '153_S.mp4', '148_S.mp4', '153_F.mp4', '159_M.mp4', '154_S.mp4', '145_M.mp4', '158_M.mp4', '143_M.mp4', '145_F.mp4', '147_S.mp4', '143_T.mp4', '143_F.mp4', '149_M.mp4', '145_T.mp4', '144_F.mp4', '153_M.mp4', '148_M.mp4', '146_T.mp4', '125_M.mp4', '127_M.mp4', '126_M.mp4', '124_M.mp4', '124_F.mp4', '126_S.mp4', '126_F.mp4', '124_S.mp4', '126_T.mp4', '124_T.mp4', '127_F.mp4', '127_S.mp4', '125_T.mp4', '142_M.mp4', '138_M.mp4', '140_M.mp4', '137_S.mp4', '137_F.mp4', '141_M.mp4', '139_M.mp4', '137_M.mp4', '139_T.mp4', '136_M.mp4', '140_F.mp4', '138_F.mp4', '142_F.mp4', '116_T.mp4', '114_T.mp4', '116_W.mp4', '112_T.mp4', '115_T.mp4', '115_W.mp4', '111_W.mp4', '115_S.mp4', '115_SU.mp4', '113_W.mp4', '111_T.mp4', '109_S.mp4', '109_F.mp4', '109_T.mp4', '108_F.mp4', '108_S.mp4', '108_T.mp4', '106_M.mp4', '106_T.mp4', '108_M.mp4', '104_S.mp4', '106_F.mp4', '109_M.mp4', '103_F.mp4', '103_S.mp4', '101_F.mp4', '107_S.mp4', '107_F.mp4', '123_M.mp4', '122_M.mp4', '119_F.mp4', '122_T.mp4', '121_W.mp4', '123_T.mp4', '121_T.mp4', '123_W.mp4', '121_F.mp4', '123_S.mp4', '123_F.mp4', '121_S.mp4', '132_T.mp4', '134_S.mp4', '129_T.mp4', '134_F.mp4', '129_F.mp4', '134_T.mp4', '132_S.mp4', '132_F.mp4', '130_S.mp4', '129_S.mp4', '131_T.mp4', '131_F.mp4', '135_M.mp4', '131_M.mp4', '128_M.mp4', '133_M.mp4', '134_M.mp4', '132_M.mp4', '130_M.mp4', '129_M.mp4']}
re_analyse = [i for i in problem_vids['LED not observed']]
for i in re_analyse:
    print(f'running reduced threshold analysis for {i}')

    # find video path again and run process_video again
    
    problem_vid_path = list(video_path.glob(f'**/{i}'))[0]
    attempt = process_video(problem_vid_path, False, False, 2, [], problem_vids, sensitive = True)
    if attempt == False:
        print(f'failed to process {i}')
    else:
        print(f'successfully processed {i}')
        problem_vids['LED not observed'].remove(i)
print(f'problems found in {problem_vids}, after running reduced threshold analysis')
# Out:
# running reduced threshold analysis for 146_M.mp4
# 146_M.mp4
# 100%|██████████| 5400/5400 [03:15<00:00, 27.55it/s]
# LED not observed in 146_M.mp4
# failed to process 146_M.mp4
# running reduced threshold analysis for 157_S.mp4
# 157_S.mp4
# 100%|██████████| 5400/5400 [03:14<00:00, 27.82it/s]
# LED not observed in 157_S.mp4
# failed to process 157_S.mp4
# running reduced threshold analysis for 155_F.mp4
# 155_F.mp4
# 100%|██████████| 5400/5400 [03:14<00:00, 27.70it/s]
# ['155_F.mp4', '88.96', '92.93', 2667.0, 2786.0]
# successfully processed 155_F.mp4
# running reduced threshold analysis for 148_T.mp4
# 148_T.mp4
# 100%|██████████| 5400/5400 [03:14<00:00, 27.77it/s]
# LED not observed in 148_T.mp4
# failed to process 148_T.mp4
# running reduced threshold analysis for 153_S.mp4
# 153_S.mp4
# 100%|██████████| 5580/5580 [03:25<00:00, 27.17it/s]
# LED not observed in 153_S.mp4
# failed to process 153_S.mp4
# running reduced threshold analysis for 148_S.mp4
# 148_S.mp4
# ...

# %%
# %run -i scripts/Interpolate_convert_mm_M.py
# Out:
# 232 csv files found
# Ran: data/output/subset/157/157_F_1.csv, saved to data/output/inter_mm/157/157_F_1_INTER_MM.csv
# Ran: data/output/subset/157/157_F_0.csv, saved to data/output/inter_mm/157/157_F_0_INTER_MM.csv
# Ran: data/output/subset/157/157_F_2.csv, saved to data/output/inter_mm/157/157_F_2_INTER_MM.csv
# Ran: data/output/subset/157/157_F_3.csv, saved to data/output/inter_mm/157/157_F_3_INTER_MM.csv
# Ran: data/output/subset/157/157_T_2.csv, saved to data/output/inter_mm/157/157_T_2_INTER_MM.csv
# Ran: data/output/subset/157/157_M_0.csv, saved to data/output/inter_mm/157/157_M_0_INTER_MM.csv
# Ran: data/output/subset/157/157_M_1.csv, saved to data/output/inter_mm/157/157_M_1_INTER_MM.csv
# Ran: data/output/subset/157/157_T_3.csv, saved to data/output/inter_mm/157/157_T_3_INTER_MM.csv
# Ran: data/output/subset/157/157_T_1.csv, saved to data/output/inter_mm/157/157_T_1_INTER_MM.csv
# ...

# %%
# %run -i scripts/data_inter_mm_analyse.py --csv_path ./data/csv/week_12/ --debug
# Out:
# 167 csv files found
# ...

# %%
# %run -i scripts/SUBSET_CSV_M_A.py --csv_path ./data/csv/week_12/143-160 --subsets "[(-6, -3), (-3, 'start'), ('start', 'end'), ('end', 3)]"
# Out:
# found csv files: 70
# Ran: data/csv/week_12/143-160/144_M.csv, saved to data/output/subset/144/144_M_0.csv
# Ran: data/csv/week_12/143-160/144_M.csv, saved to data/output/subset/144/144_M_1.csv
# Ran: data/csv/week_12/143-160/144_M.csv, saved to data/output/subset/144/144_M_2.csv
# Ran: data/csv/week_12/143-160/144_M.csv, saved to data/output/subset/144/144_M_3.csv
# Ran: data/csv/week_12/143-160/153_T.csv, saved to data/output/subset/153/153_T_0.csv
# Ran: data/csv/week_12/143-160/153_T.csv, saved to data/output/subset/153/153_T_1.csv
# Ran: data/csv/week_12/143-160/153_T.csv, saved to data/output/subset/153/153_T_2.csv
# Ran: data/csv/week_12/143-160/153_T.csv, saved to data/output/subset/153/153_T_3.csv
# Ran: data/csv/week_12/143-160/157_F.csv, saved to data/output/subset/157/157_F_0.csv
# Ran: data/csv/week_12/143-160/157_F.csv, saved to data/output/subset/157/157_F_1.csv
# Ran: data/csv/week_12/143-160/157_F.csv, saved to data/output/subset/157/157_F_2.csv
# ...

# %%
# interpolate
# df.interpolate(axis=1,limit = inter_limit, limit_area = 'inside', inplace=True)

# %%
# %run scripts/LED_times.py --video_path data/videos/week_12/ --output_path data/output/no_thresh/ --no_hist_thresh
# Out:
#  total videos found are 242
# 160_M.mp4
# 100%|██████████| 5400/5400 [03:16<00:00, 27.42it/s]
# ['160_M.mp4', '88.49', '93.46', 2653.0, 2802.0]
# 155_S.mp4
# 100%|██████████| 5400/5400 [03:14<00:00, 27.78it/s]
# ['155_S.mp4', '89.52', '93.26', 2684.0, 2796.0]
# 157_F.mp4
# 100%|██████████| 5370/5370 [03:09<00:00, 28.28it/s]
# ['157_F.mp4', '119.92', '123.89', 3595.0, 3714.0]
# 153_T.mp4
# 100%|██████████| 5400/5400 [03:15<00:00, 27.62it/s]
# ['153_T.mp4', '89.56', '93.53', 2685.0, 2804.0]
# 144_M.mp4
# 100%|██████████| 5400/5400 [03:15<00:00, 27.56it/s]
# ['144_M.mp4', '90.29', '94.26', 2707.0, 2826.0]
# 146_M.mp4
# 100%|██████████| 5400/5400 [03:16<00:00, 27.53it/s]
# LED not observed in 146_M.mp4
# 151_T.mp4
# 100%|██████████| 5400/5400 [03:15<00:00, 27.62it/s]
# ['151_T.mp4', '89.32', '93.29', 2678.0, 2797.0]
# ['151_T.mp4', '149.32', '153.29', 4476.0, 4595.0]
# 157_S.mp4
# 100%|██████████| 5400/5400 [03:16<00:00, 27.55it/s]
# LED not observed in 157_S.mp4
# 155_F.mp4
# ...

# %%
# %run scripts/data_mm_analyse.py --csv_path ./data/csv/week_12/ --debug
# Out:
# 167 csv files found
# ...

# %%
'''
1                1  148.60748 -433.811040  0.9739999771118164  139.45148   
1 -425.321536                 1.0  125.90956 -417.850432  0.9909999966621399   
1  ...  0.9570000171661377  90.62172 -409.424768              1.0   0.059080   
1   0.012320    0.000560    4.473010   2.421160  1.359619  
'''
weights = np.asarray([0.9739999771118164, 1.0, 0.9909999966621399, 0.9570000171661377, 1.0])
weight_pos = weights/weights.sum()
np.average([0.059080, 0.012320, 0.000560, 4.473010, 2.421160], weights=weight_pos)
# Out:
# 1.3759141686094791

# %%
csv_file = Path('data/csv/week_12/143-160/148_M.csv')
output_path = Path('data/output/')
csv_path = Path('data/csv/week_12/')
output_csv_path = output_path / csv_file.relative_to(csv_path)
os.makedirs(output_csv_path.parent, exist_ok=True)

# %%
import pandas as pd
led = pd.read_csv(Path('data/output/LED_times.csv'))
csv_file = Path("data/160_M.csv")
print(csv_file.stem)
# led_row = led.loc[csv_file.stem isin led['name']]
# find the row in the led dataframe that contains the csv_file name
led_row = led[led["name"].str.contains(csv_file.stem)]
# led_row = led.loc[csv_file.stem in (led['name'])]
print(led_row["start time(s)"].values)
# Out:
# 160_M
# [88.49]

# %%
import pandas as pd
import numpy as np  
from pathlib import Path
debug = True
csv_file = Path("./data/csv/without_led/control/1/102_F.csv")
df = pd.read_csv(csv_file, header=None)

df.columns = df.iloc[2] + "_" + df.iloc[3] # naming the columns as Tail_x, Tail_y, Tail_likelihood, etc.
df.drop([0,1,2,3], inplace=True) # remove the first 4 rows. Contains model name, individual name, body part and x/y/likelihood
df.reset_index(drop=True, inplace=True) # resets the row index

# convert to numeric dtype from str
df = df.apply(pd.to_numeric, downcast = 'float' ,errors='coerce')



y_columns = [col for col in df.columns if "_y" in col]
# surface = df[y_columns].max(axis=1).average
surface = df[y_columns].max(axis=0).mean()
print(surface)

y_mean = df[y_columns].mean(axis=1, skipna=True)

df["distance_surface"] = y_mean - surface

print(max(df["distance_surface"].values))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 6
#       4 debug = True
#       5 csv_file = Path("./data/csv/without_led/control/1/102_F.csv")
# ----> 6 df = pd.read_csv(csv_file, header=None)
#       8 df.columns = df.iloc[2] + "_" + df.iloc[3] # naming the columns as Tail_x, Tail_y, Tail_likelihood, etc.
#       9 df.drop([0,1,2,3], inplace=True) # remove the first 4 rows. Contains model name, individual name, body part and x/y/likelihood
#
# File ~/opt/anaconda3/envs/ari_cv2/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import os


csv_path = Path("./data/output/final/")
csv_files = list(csv_path.glob("**/*.csv"))
print(len(csv_files))
for csv in csv_files:
    df = pd.read_csv(csv)
# checking if the max of the distance_surface column is less than 0, and % of frames that are less than 0
    if max(df["distance_surface"].values) > 0:
        print(csv)
        print(max(df["distance_surface"].values))
        print(len(df[df["distance_surface"] > 0])/len(df)*100)
        print()

# findings show that only 5-6 videos have > 1% of frames with distance_surface > 0
# how to account for these? count as jitter?
# or remove them from the analysis?
# or remove them from the analysis, but keep them in the csv for future analysis?
# Out:
# 241
# data/output/final/uroa/1/125_M.csv
# 17.693787
# 0.016835016835016835
#
# data/output/final/uroa/1/146_M.csv
# 26.857819
# 0.07407407407407407
#
# data/output/final/uroa/1/105_M.csv
# 5.290436
# 0.018315018315018316
#
# data/output/final/uroa/1/133_M.csv
# 41.265503
# 2.014260249554367
#
# data/output/final/uroa/1/129_M.csv
# 14.018036
# 0.7407407407407408
#
# data/output/final/uroa/1/130_M.csv
# 5.3819885
# 0.016025641025641024
#
# data/output/final/uroa/1/148_M.csv
# 61.8562
# 1.2021857923497268
#
# data/output/final/uroa/4/129_S.csv
# 22.694046
# 0.05555555555555555
#
# data/output/final/uroa/4/148_S.csv
# 23.54802
# 0.015873015873015872
#
# data/output/final/uroa/4/108_S.csv
# 141.3482
# 0.29304029304029305
#
# data/output/final/uroa/4/126_S.csv
# 42.97319
# 0.4629629629629629
#
# data/output/final/uroa/4/104_S.csv
# 19.492706
# 0.1111111111111111
#
# data/output/final/uroa/4/116_SU.csv
# 13.184097
# 0.0925925925925926
#
# data/output/final/uroa/4/121_S.csv
# 17.032028
# ...

# %%
# testing find-coordinate in led times
# %run scripts/LED_times.py --video_path data/videos/d48_test/ --output_path data/output/find_coords_test/ --no_hist_thresh
# Out:
#  total videos found are 4
# d48_35_F1.mp4
#  48%|████▊     | 2636/5460 [01:29<01:37, 29.00it/s]
# None
# None
# None
# None
# None
# None
#  48%|████▊     | 2642/5460 [01:29<01:45, 26.69it/s]
# None
# None
# None
# None
# None
# None
#  48%|████▊     | 2648/5460 [01:29<01:43, 27.18it/s]
# None
# None
# None
# None
# None
# None
#  49%|████▊     | 2654/5460 [01:29<01:46, 26.26it/s]
# None
# None
# None
# None
# None
# None
#  49%|████▊     | 2661/5460 [01:30<01:41, 27.70it/s]
# None
# None
# None
# None
# None
# None
#  49%|████▉     | 2664/5460 [01:30<01:46, 26.19it/s]
# None
# None
# None
# None
# None
#  49%|████▉     | 2670/5460 [01:30<01:49, 25.57it/s]
# None
# None
# None
# None
# None
# None
#  49%|████▉     | 2676/5460 [01:30<01:46, 26.24it/s]
# None
# None
# None
# None
# None
#  49%|████▉     | 2682/5460 [01:30<01:43, 26.74it/s]
# None
# None
# None
# None
# None
# None
#  49%|████▉     | 2688/5460 [01:31<01:43, 26.83it/s]
# None
# None
# None
# None
# None
# None
# ...
