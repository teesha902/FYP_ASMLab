# %% [markdown]
# # setup

# %%
# !conda env list
# Make sure the custom env is created
# Out:
# # conda environments:
# #
# base                     C:\Users\arite\miniconda3
# ASM_Lab               *  C:\Users\arite\miniconda3\envs\ASM_Lab

# %%
# %pip install -r requirements.txt
# Out:
# ...
#      ---------------------------------------- 78.5/78.5 kB ? eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # DLC

# %% [markdown]
# # Analysis

# %% [markdown]
# #Subset CSV to subset it into CSVs
#
# Ensure csvs are in data/csv/

# %%
# !python scripts/SUBSET_CSV_M.py
# Out:
# 118_FDLC_resnet50_KF_FullMay24shuffle1_50000_el_filtered.csv
# Traceback (most recent call last):
#   File "c:\Users\arite\Desktop\ASM RA\ASM_Killifish_repo\scripts\SUBSET_CSV_M.py", line 28, in <module>
#     exp_time =int(csv.iloc[0,22])
#   File "c:\Users\arite\miniconda3\envs\ASM_Lab\lib\site-packages\pandas\core\indexing.py", line 1066, in __getitem__
#     return self.obj._get_value(*key, takeable=self._takeable)
#   File "c:\Users\arite\miniconda3\envs\ASM_Lab\lib\site-packages\pandas\core\frame.py", line 3912, in _get_value
#     series = self._ixs(col, axis=1)
#   File "c:\Users\arite\miniconda3\envs\ASM_Lab\lib\site-packages\pandas\core\frame.py", line 3726, in _ixs
#     label = self.columns[i]
#   File "c:\Users\arite\miniconda3\envs\ASM_Lab\lib\site-packages\pandas\core\indexes\base.py", line 5363, in __getitem__
#     return getitem(key)
# IndexError: index 22 is out of bounds for axis 0 with size 16
