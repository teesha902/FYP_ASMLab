# %% [markdown]
# # Modular Dabest Visualisations
#
# output is saved to ./data/visualisation/{EXPERIMENT_NAME}_modular/
#
# In this example, ive shown how to use the modular visualisation functions for d48 and d77 led timings.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from pathlib import Path
import random
import os
from scripts.visualisation import * # the visualisation module created, contains the functions to be used

plt.style.use('seaborn')
# Out:
# C:\Users\Aritejh\AppData\Local\Temp\ipykernel_9800\3632429562.py:10: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# ## Setup Dataframes
# we set up the LED df, as well as the random 3s before LED dataframe below.
#
# The metrics recorded are cumulative distance travelled, avg vel, avg acc, avg head-tail angle, minimum distance to LED (max height reached), % of frames above initial, magnitude of y travelled (from start to highest point), start to highest trajectory angle,
#
# The create_master_dataframe checks which columns are needed, and creates a master dataframe that is used downstream for visualisations. This is done so that we do not have to go back and create the dataframe for every new visualisation of the same experiment set data.
#
# For creating new metrics, they have to be declared in create_master_dataframe and columns

# %%
# These are the data points created for analysis 
columns = ['name',
 'uroa_control',
 'day',
 'dist',
 'vel',
 'acc',
 'head_angle',
 'dist_surface',
 'y_up',
 'y_mag',
 'trajectory_angle',
 'start_y_from_led',
 'end_trajectory_angle']

# %%
# parameters with their meanings 
parameter_dict = {
    'dist': 'total distance travelled',
    'vel': 'average velocity',
    'acc': 'average acceleration',
    'head_angle': 'average tail-head angle',
    'dist_surface': 'distance from highest point in trajectory to LED',
    'y_up' : 'percentage of frames with y above starting y',
    'y_mag': 'magnitude of y between start and highest point',
    'trajectory_angle': 'angle between start and highest point',
    'start_y_from_led': 'distance from LED to start point',
    'end_trajectory_angle': 'angle between start and end point'
}

# %% [markdown]
# ### modular plots

# %%
# creating a modular graph generator - Unpaired 
# 1. create dfs for each set of data
# you can create either LED or before LED dfs
EXPERIMENT_SET = 'd48_d77_LED'

df1_dlc_csv_path = Path("./data/output/d48_vr03_final")
df1_led_csv_path = Path("./data/output/d48_LED_times.csv")
df2_dlc_csv_path = Path("./data/output/d77_final")
df2_led_csv_path = Path("./data/output/d77_LED_times.csv")

save_path = Path(f'./data/visualisation/{EXPERIMENT_SET}_modular/')

# FOR LED: create_master_dataframe(columns, csv_files, led_csv, random_pre_led = False)
# FOR BEFORE LED: create_master_dataframe(columns, csv_files, led_csv, random_pre_led = True)

df1_csv_files = list(df1_dlc_csv_path.glob("**/*.csv"))
df1_led_csv = pd.read_csv(df1_led_csv_path)
df2_csv_files = list(df2_dlc_csv_path.glob("**/*.csv"))
df2_led_csv = pd.read_csv(df2_led_csv_path)

df1 = create_master_dataframe(columns, df1_csv_files, df1_led_csv, random_pre_led = False)
df2 = create_master_dataframe(columns, df2_csv_files, df2_led_csv, random_pre_led = False)


parameters = df1.columns[3:]
# Out:
# d48_24_M1.csv
# d48_25_M1.csv
# d48_27_M1.csv
# d48_30_M1.csv
# d48_32_M1.csv
# d48_33_M1.csv
# d48_34_M1.csv
# d48_36_M1.csv
# d48_38_M1.csv
# d48_39_M1.csv
# d48_40_M1.csv
# d48_41_M1.csv
# d48_45_M1.csv
# d48_46_M1.csv
# d48_50_M1.csv
# d48_51_M1.csv
# d48_54_M1.csv
# d48_56_M1.csv
# d48_57_M1.csv
# d48_59_M1.csv
# d48_60_M1.csv
# d48_62_M1.csv
# d48_63_M1.csv
# d48_67_M1.csv
# d48_68_M1.csv
# d48_73_M1.csv
# d48_74_M1.csv
# d48_75_M1.csv
# d48_78_M1.csv
# d48_79_M1.csv
# d48_81_M1.csv
# d48_82_M1.csv
# d48_84_M1.csv
# d48_87_M1.csv
# d48_24_T1.csv
# d48_25_T1.csv
# d48_27_T1.csv
# d48_30_T3.csv
# d48_32_T3.csv
# d48_33_T1.csv
# d48_34_T1.csv
# d48_36_T1.csv
# d48_38_T1.csv
# d48_39_T1.csv
# d48_40_T1.csv
# d48_41_T1.csv
# d48_45_T1.csv
# d48_46_T1.csv
# d48_50_T1.csv
# d48_51_T1.csv
# d48_54_T1.csv
# d48_56_T1.csv
# d48_57_T1.csv
# d48_59_T1.csv
# d48_60_T1.csv
# d48_62_T1.csv
# d48_63_T1.csv
# d48_67_T1.csv
# d48_68_T1.csv
# d48_73_T1.csv
# d48_74_T1.csv
# d48_75_T1.csv
# d48_78_Thu1.csv
# d48_79_Thu1.csv
# d48_81_Thu1.csv
# d48_82_Thu1.csv
# d48_84_Thu1.csv
# d48_87_T1.csv
# d48_24_F1.csv
# d48_25_F1.csv
# d48_27_F1.csv
# d48_30_F1.csv
# d48_32_F1.csv
# d48_33_F1.csv
# d48_34_F1.csv
# d48_36_F1.csv
# d48_38_F1.csv
# d48_39_F1.csv
# d48_40_F1.csv
# d48_41_F1.csv
# d48_45_F1.csv
# d48_46_F1.csv
# d48_50_F1.csv
# d48_51_F1.csv
# d48_54_F1.csv
# d48_56_F1.csv
# d48_57_F1.csv
# d48_59_F1.csv
# d48_60_F1.csv
# LED file not found for d48_60_F1.csv
# d48_62_F1.csv
# d48_63_F1.csv
# d48_67_F1.csv
# d48_68_F1.csv
# d48_73_F1.csv
# d48_74_F1.csv
# d48_75_F1.csv
# d48_78_Sat1.csv
# d48_79_Sat1.csv
# d48_81_Sat1.csv
# d48_82_Sat1.csv
# d48_84_Sat1.csv
# d48_87_F1.csv
# d48_24_S1.csv
# d48_25_S1.csv
# d48_27_S1.csv
# d48_30_S1.csv
# d48_32_S1.csv
# d48_33_S1.csv
# d48_34_S1.csv
# d48_36_S1.csv
# d48_38_S1.csv
# d48_39_S1.csv
# d48_40_S1.csv
# d48_41_S1.csv
# d48_45_S1.csv
# d48_46_S1.csv
# d48_50_S1.csv
# d48_51_S1.csv
# d48_54_S1.csv
# d48_56_S1.csv
# d48_57_S1.csv
# d48_59_S1.csv
# d48_60_S1.csv
# d48_62_S1.csv
# d48_63_S1.csv
# d48_67_S1.csv
# d48_68_S1.csv
# d48_73_S1.csv
# d48_74_S1.csv
# d48_75_S1.csv
# d48_78_Sun1.csv
# d48_79_Sun1.csv
# d48_81_Sun1.csv
# d48_82_Sun1.csv
# d48_84_Sun1.csv
# d48_87_S1.csv
# d48_23_M1.csv
# d48_26_M1.csv
# d48_28_M1.csv
# d48_29_M1.csv
# d48_31_M1.csv
# d48_35_M1.csv
# d48_37_M1.csv
# d48_42_M1.csv
# d48_43_M1.csv
# d48_44_M1.csv
# d48_47_M1.csv
# d48_48_M1.csv
# d48_49_M1.csv
# d48_52_M1.csv
# d48_53_M1.csv
# d48_55_M1.csv
# d48_58_M1.csv
# d48_64_M1.csv
# d48_65_M1.csv
# d48_66_M1.csv
# d48_69_M1.csv
# d48_70_M1.csv
# d48_71_M1.csv
# d48_72_M1.csv
# d48_76_M1.csv
# d48_77_M1.csv
# d48_80_M1.csv
# d48_83_M1.csv
# d48_85_M1.csv
# d48_86_M1.csv
# d48_23_T1.csv
# d48_26_T1.csv
# d48_28_T1.csv
# LED file not found for d48_28_T1.csv
# d48_29_T3.csv
# d48_31_T3.csv
# d48_35_T1.csv
# d48_37_T1.csv
# d48_42_T1.csv
# d48_43_T1.csv
# d48_44_T1.csv
# d48_47_T1.csv
# d48_48_T1.csv
# d48_49_T1.csv
# d48_52_T1.csv
# d48_53_T1.csv
# d48_55_T1.csv
# d48_58_T1.csv
# d48_64_T1.csv
# d48_65_T1.csv
# d48_66_T1.csv
# d48_69_T1.csv
# d48_70_T1.csv
# d48_71_T1.csv
# d48_72_T1.csv
# d48_76_Thu1.csv
# d48_77_Thu1.csv
# d48_80_Thu1.csv
# d48_83_Thu1.csv
# d48_85_Thu1.csv
# d48_86_T1.csv
# d48_23_F1.csv
# d48_26_F1.csv
# d48_28_F1.csv
# d48_29_F1.csv
# d48_31_F1.csv
# d48_35_F1.csv
# d48_37_F1.csv
# d48_42_F1.csv
# d48_43_F1.csv
# d48_44_F1.csv
# d48_47_F1.csv
# d48_48_F1.csv
# d48_49_F1.csv
# d48_52_F1.csv
# d48_53_F1.csv
# d48_55_F1.csv
# d48_58_F1.csv
# d48_64_F1.csv
# d48_65_F1.csv
# d48_66_F1.csv
# d48_69_F1.csv
# d48_70_F1.csv
# d48_71_F1.csv
# d48_72_F1.csv
# d48_76_Sat1.csv
# d48_77_Sat1.csv
# d48_80_Sat1.csv
# LED file not found for d48_80_Sat1.csv
# d48_83_Sat1.csv
# d48_85_Sat1.csv
# d48_86_Sat1.csv
# d48_23_S1.csv
# d48_26_S1.csv
# d48_28_S1.csv
# d48_29_S1.csv
# d48_31_S1.csv
# d48_35_S1.csv
# d48_37_S1.csv
# d48_42_S1.csv
# d48_43_S1.csv
# d48_44_S1.csv
# d48_47_S1.csv
# d48_48_S1.csv
# d48_49_S1.csv
# d48_52_S1.csv
# d48_53_S1.csv
# d48_55_S1.csv
# d48_58_S1.csv
# d48_64_S1.csv
# d48_65_S1.csv
# d48_66_S1.csv
# d48_69_S1.csv
# d48_70_S1.csv
# d48_71_S1.csv
# d48_72_S1.csv
# d48_76_Sun1.csv
# d48_77_Sun1.csv
# d48_80_Sun1.csv
# LED file not found for d48_80_Sun1.csv
# d48_83_Sun1.csv
# d48_85_Sun1.csv
# d48_86_Sun1.csv
# name 252
# uroa_control 252
# day 252
# dist 252
# vel 252
# acc 252
# head_angle 252
# dist_surface 252
# y_up 252
# y_mag 252
# trajectory_angle 252
# start_y_from_led 252
# end_trajectory_angle 252
#   name  uroa_control  day         dist        vel         acc  head_angle  \
# 0   24             0    1   222.332294   2.390670   71.720091  231.737525
# 1   25             0    1   417.187595   4.485888  134.576635  221.288280
# 2   27             0    1  1047.661008  11.387620  341.628571  101.496177
# 3   30             0    1   210.694790   2.315327   69.459817  159.182599
# 4   32             0    1   122.841579   1.349907   40.497222  314.908377
#
#    dist_surface       y_up       y_mag  trajectory_angle  start_y_from_led  \
# 0   -310.910100  37.634409   20.004766         45.903963        -330.91486
# 1   -114.820496  18.279570   36.583608         70.103145        -151.40408
# 2    -94.290695  80.434783  304.404498         82.903000        -398.69520
# 3   -203.087510  98.901099  109.458586        120.821472        -312.54608
# 4   -281.658020  25.274725    4.531356          4.000300        -286.18936
#
#    end_trajectory_angle
# 0            325.326253
# 1            238.990750
# 2            102.406342
# 3            119.480925
# 4              3.912309
# d77_24_M1.csv
# d77_25_M1.csv
# d77_27_M1.csv
# d77_33_M1.csv
# d77_34_M1.csv
# d77_36_M1.csv
# d77_38_M1.csv
# d77_39_M1.csv
# d77_40_M1.csv
# d77_41_M1.csv
# d77_45_M1.csv
# d77_46_M1.csv
# d77_50_M1.csv
# d77_51_M1.csv
# d77_54_M1.csv
# d77_56_M1.csv
# d77_57_M1.csv
# d77_59_M1.csv
# d77_60_M1.csv
# d77_62_M1.csv
# d77_67_M1.csv
# d77_68_M1.csv
# d77_73_M1.csv
# d77_74_M1.csv
# d77_75_M1.csv
# d77_24_T1.csv
# d77_25_T1.csv
# d77_27_T1.csv
# d77_33_Thu1.csv
# d77_34_Thu1.csv
# d77_36_Thu1.csv
# d77_38_T1.csv
# d77_39_T1.csv
# d77_40_T1.csv
# d77_41_T1.csv
# d77_45_T1.csv
# d77_46_T1.csv
# d77_50_T1.csv
# d77_51_T1.csv
# d77_54_T1.csv
# d77_56_T1.csv
# d77_57_T1.csv
# d77_59_T1.csv
# d77_60_T1.csv
# d77_61_T1.csv
# d77_62_T1.csv
# d77_67_T1.csv
# d77_68_T1.csv
# d77_73_T1.csv
# d77_74_T1.csv
# d77_75_T1.csv
# LED file not found for d77_75_T1.csv
# d77_24_F1.csv
# d77_25_F1.csv
# d77_27_F1.csv
# d77_33_Sat1.csv
# d77_34_Sat1.csv
# d77_36_Sat1.csv
# d77_38_F1.csv
# d77_39_F1.csv
# d77_40_F1.csv
# d77_41_F1.csv
# d77_45_F1.csv
# d77_46_F1.csv
# d77_50_F1.csv
# d77_51_F1.csv
# d77_54_F1.csv
# d77_56_F1.csv
# d77_57_F1.csv
# d77_59_F1.csv
# d77_60_F1.csv
# d77_61_F1.csv
# d77_62_F1.csv
# d77_67_F1.csv
# d77_68_F1.csv
# d77_73_F1.csv
# d77_74_F1.csv
# d77_75_F1.csv
# d77_24_S1.csv
# d77_25_S1.csv
# d77_27_S1.csv
# d77_33_Sun1.csv
# d77_34_Sun1.csv
# d77_36_Sun1.csv
# d77_38_S1.csv
# d77_39_S1.csv
# LED file not found for d77_39_S1.csv
# d77_40_S1.csv
# d77_41_S1.csv
# d77_45_S1.csv
# d77_46_S1.csv
# d77_50_S1.csv
# d77_51_S1.csv
# d77_54_S1.csv
# d77_56_S1.csv
# d77_57_S1.csv
# d77_59_S1.csv
# d77_60_S1.csv
# d77_61_S1.csv
# d77_62_S1.csv
# d77_67_S1.csv
# d77_68_S1.csv
# d77_73_S1.csv
# d77_74_S1.csv
# d77_75_S1.csv
# d77_23_M1.csv
# d77_26_M1.csv
# d77_35_M1.csv
# d77_37_M1.csv
# LED file not found for d77_37_M1.csv
# d77_42_M1.csv
# LED file not found for d77_42_M1.csv
# d77_43_M1.csv
# d77_44_M1.csv
# d77_47_M1.csv
# d77_48_M1.csv
# d77_49_M1.csv
# d77_52_M1.csv
# d77_53_M1.csv
# d77_55_M1.csv
# d77_58_M1.csv
# d77_63_M1.csv
# d77_64_M1.csv
# d77_66_M1.csv
# d77_69_M1.csv
# d77_70_M1.csv
# d77_71_M1.csv
# d77_72_M1.csv
# d77_23_T1.csv
# d77_26_T1.csv
# d77_35_Thu1.csv
# d77_37_Thu1.csv
# LED file not found for d77_37_Thu1.csv
# d77_42_T1.csv
# d77_43_T1.csv
# d77_44_T1.csv
# d77_47_T1.csv
# d77_48_T1.csv
# d77_49_T1.csv
# d77_52_T1.csv
# d77_53_T1.csv
# d77_55_T1.csv
# d77_58_T1.csv
# d77_63_T1.csv
# d77_64_T1.csv
# d77_66_T1.csv
# d77_69_T1.csv
# d77_70_T1.csv
# d77_71_T1.csv
# d77_72_T1.csv
# d77_23_F1.csv
# d77_26_F1.csv
# d77_35_Sat1.csv
# d77_37_Sat1.csv
# LED file not found for d77_37_Sat1.csv
# d77_42_F1.csv
# d77_43_F1.csv
# d77_44_F1.csv
# d77_47_F1.csv
# d77_48_F1.csv
# d77_49_F1.csv
# d77_52_F1.csv
# d77_53_F1.csv
# d77_55_F1.csv
# d77_58_F1.csv
# d77_63_F1.csv
# d77_64_F1.csv
# d77_66_F1.csv
# d77_69_F1.csv
# d77_70_F1.csv
# d77_71_F1.csv
# d77_72_F1.csv
# d77_23_S1.csv
# d77_26_S1.csv
# d77_35_Sun1.csv
# d77_37_Sun1.csv
# LED file not found for d77_37_Sun1.csv
# d77_42_S1.csv
# d77_43_S1.csv
# d77_44_S1.csv
# d77_47_S1.csv
# d77_48_S1.csv
# d77_49_S1.csv
# d77_52_S1.csv
# d77_53_S1.csv
# d77_55_S1.csv
# d77_58_S1.csv
# d77_63_S1.csv
# d77_64_S1.csv
# d77_66_S1.csv
# d77_69_S1.csv
# d77_70_S1.csv
# d77_71_S1.csv
# d77_72_S1.csv
# name 180
# uroa_control 180
# day 180
# dist 180
# vel 180
# acc 180
# head_angle 180
# dist_surface 180
# y_up 180
# y_mag 180
# trajectory_angle 180
# start_y_from_led 180
# end_trajectory_angle 180
#   name  uroa_control  day        dist       vel         acc  head_angle  \
# 0   24             0    1  644.813640  7.085864  212.575914  185.008028
# 1   25             0    1  785.480694  8.631656  258.949680  136.247171
# 2   27             0    1  425.361616  4.674303  140.229095  172.567514
# 3   33             0    1   93.563276  1.028168   30.845035  232.467231
# 4   34             0    1   90.543850  0.994987   29.849619  187.213789
#
#    dist_surface       y_up       y_mag  trajectory_angle  start_y_from_led  \
# 0     -84.11203  98.901099  183.903041         64.416183        -268.01510
# 1     -89.65170  98.901099  362.494780         70.563866        -282.89450
# 2     -75.42316  78.021978   64.186406        108.224189        -139.60956
# 3    -217.45868   0.000000    0.000000        360.000000        -217.45868
# 4    -257.50840  98.901099   22.827430        145.537743        -280.33585
#
#    end_trajectory_angle
# 0             38.681332
# 1             92.467903
# 2            120.188715
# 3            290.343715
# 4            168.170183

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# check to see paired and unpaired numbers for each group

# %% [markdown]
# ### unpaired plots

# %%
import dabest
os.makedirs(save_path, exist_ok=True)
for parameter in parameters:
    param_save_path = save_path/Path(parameter)
    os.makedirs(param_save_path, exist_ok=True)
    # initialize the figure
    fig, axes = plt.subplots(2, 4, figsize=(25,10), sharey=True)
    plt.suptitle(f"{parameter_dict[parameter]}, comparison", fontsize=22)
    fig.subplots_adjust(hspace=0.7) # leave more space between subplots

    # 2. group the dfs
    param_df1 = df1[["name","uroa_control", "day", parameter]].groupby(["day", "uroa_control"])
    param_df2 = df2[["name","uroa_control", "day", parameter]].groupby(["day", "uroa_control"])
    
    # param_df.to_csv(save_path/Path(f"{parameter}_merged.csv"), index=False)
    # param_df = param_df.groupby(["uroa_control", "day"])
    keys = list(param_df1.groups.keys())

    for i, axes in enumerate(axes.flat):
    # # for i in range(len(keys)):
        # get the group for each axes
        param_condition_day_df = param_df1.get_group(keys[i]).reset_index(drop=True)
        param_condition_day_df2 = param_df2.get_group(keys[i]).reset_index(drop=True)
        # print(param_condition_day_df.head())
        # print(param_condition_day_df2.head())
        # print(parameter)

        # add parameter column from df2 to df1
        param_condition_day_df[parameter+"_df2"] = param_condition_day_df2[parameter]
        param_condition_day_df.to_csv(param_save_path/Path(f"{parameter}_{i}_merged.csv"), index=False)
        # 3. create dabest object
        dabest_obj = dabest.load(param_condition_day_df, idx=(f'{parameter}', f'{parameter}_df2'))
        # 4. save dabest tests (CHOOSE TYPE OF DIFFERENCE TEST)
        tests_df = dabest_obj.mean_diff.statistical_tests
        tests_df.to_csv(param_save_path/Path(f"{parameter}_{i}_dabest_tests.csv"), index=False)
        # 5. plot dabest graph
        dabest_obj.mean_diff.plot(ax=axes)
        
        plt.tight_layout()
        # set the title for the plot
        axes.set_title(f"Day {keys[i][0]} {'uroa' if keys[i][1] == 1 else 'control'}", fontsize=15)

    # 6. save graph
    plt.savefig(param_save_path/Path(f"{parameter}_dabest.png"))
    plt.savefig(param_save_path/Path(f"{parameter}_dabest.svg"))
    plt.show()
    plt.close()

# %% [markdown]
# ### paired plots

# %%
import dabest

save_path = Path(f'./data/visualisation/{EXPERIMENT_SET}_paired_modular/')

os.makedirs(save_path, exist_ok=True)
for parameter in parameters:
    param_save_path = save_path/Path(parameter)
    os.makedirs(param_save_path, exist_ok=True)

    # initialize the figure
    fig, axes = plt.subplots(2, 4, figsize=(25,10), sharey=True)
    plt.suptitle(f"{parameter_dict[parameter]}, comparison", fontsize=22)
    fig.subplots_adjust(hspace=0.7) # leave more space between subplots

    # 2. merge the dfs

    # uroa_control | day | {parameter}_df1 | {parameter}_df2
    param_df = pd.merge(df1[["name","uroa_control", "day", parameter]], df2[["name","uroa_control", "day", parameter]], on=["name","day", "uroa_control"], suffixes=("_df1", "_df2"), how='inner')
    
    param_df.to_csv(param_save_path/Path(f"{parameter}_merged.csv"), index=False)
    param_df = param_df.groupby(["uroa_control", "day"])
    keys = list(param_df.groups.keys())

    for i, axes in enumerate(axes.flat):
        # get the group for each axes
        param_condition_day_df = param_df.get_group(keys[i]).dropna().reset_index(drop=True)
        # print(param_condition_day_df.head())
        # print(len(param_condition_day_df))

        # 3. create dabest object
        dabest_obj = dabest.load(param_condition_day_df, idx=(f'{parameter}_df1', f'{parameter}_df2'), paired= "baseline", id_col="name")
        
        # 4. save dabest tests (CHOOSE TYPE OF DIFFERENCE TEST)
        tests_df = dabest_obj.mean_diff.statistical_tests
        tests_df.to_csv(param_save_path/Path(f"{parameter}_{i}_dabest_tests.csv"), index=False)
        # 5. plot dabest graph
        dabest_obj.mean_diff.plot(ax=axes)
        
        plt.tight_layout()
        # set the title for the plot
        axes.set_title(f"Day {keys[i][1]} {'uroa' if keys[i][0] == 1 else 'control'}", fontsize=15)

    # 6. save graph
    plt.savefig(param_save_path/Path(f"{parameter}_dabest.png"))
    plt.savefig(param_save_path/Path(f"{parameter}_dabest.svg"))
    plt.show()
    plt.close()
