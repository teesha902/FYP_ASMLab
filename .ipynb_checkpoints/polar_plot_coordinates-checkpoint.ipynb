# %% [raw]
# ---
# title: "Polar Plot coordinates"
# format: gfm
# jupyter: python3
# ---

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
2+2
# Out:
# 4

# %%
print("This is some text")
# Out:
# This is some text
